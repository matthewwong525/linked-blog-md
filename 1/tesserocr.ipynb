# %%
# !apt-get update
# !apt-get install -y tesseract-ocr
# !apt-get install -y libtesseract-dev

# %%
# !pip install tesserocr pillow

# %%
# Only run below if using colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Set the TESSDATA_PREFIX environment variable
os.environ['TESSDATA_PREFIX'] = '/usr/share/tesseract-ocr/4.00/tessdata/'

import tesserocr
from PIL import Image

# Test with an example image
path = '/path/to/folder/'
image = Image.open(path + 'remove_borders_Bryn/removeBordersMasking/data/images/cargaaerea_bosch_bosch1_page1.jpeg')
text = tesserocr.image_to_text(image, psm=6, oem=1)
print(text)
# Out:
# () BOSCH
# ©)
# Bosch Automotive Service Solutions GmbH
# Porschestrasse 4
# 63512 Hainburg - Deutschland
# TEL ++ 49 6182 959-0
# FAX ++ 49 6182 959-245
# www.bosch.com
# Bosch Automotive Service Solutions GmbH - Porschestrasse 4- D-63512 Hainburg In voi ce
# Bosch Automotive Number / Date 200278982 / 16.04.2021
# Service Solutions, S.A. de C.V. Del.Number / Date 82975471 / 09.04.2021
# AV-TEJOCOTESSIN Lit2 Our Order No./Date 1320204 / 08.04.2021
# PARQUE INDUSTRIAL SMO CUAUTITLAN . vi Order Ni 956580
# 54769 IZCALLI, MEXICO SUGSISEH ISS:
# MEXICO Customer number 20000037
# Your tax-id-code
# Your fiscal code
# Contact Customer Service Support
# Telephone number
# Supplier number
# Delivery address
# BOSCH Automotive Service Solutions,
# Parque Industrial San Martin Obispo
# Av. Tejocotes S/N L.T.
# 54769 CUAUTITLAN IZCALLI
# We calculate according our general terms and conditions
# Terms of payment: 30 days net
# ee oT SY): FCA, Free Carrier Shipping Warehouse Currency EUR
# Forwarding agent: Panalpina Welttransport Deutschland
# item article no. description ME Qty. net amou tax
# AIB
# 10 JLR-303-1692-04 Support Beam Adaptor Kit PCE 3 59,43 178,30 B
# country of origin Germany
# customs tariff code 73269098
# Net Weight 7,500 KG
# NO PREFERENTIAL ORIGIN
# Bosch Automotive Service Solutions GmbH
# Registered office of the company is: Am Dérrenhof 1 in 85131 Pollenfeld/ District court Ingolstadt HRB 86,
# Managing Director Carsten Henkel, Dr. Pio Torre Flores
# Deutsche Bank, Stuttgart; Account No. 166 359 000; BIN 600 700 70; SWIFT DEUTDESSXXX; IBAN DE48 6007 0070 0166 3590 00
# USt-ldNr. / VAT registration-no. / N°d'identification TVA: DE128579454 Tax code: 11/290/09930 Tax Office: Bad Segeberg,
# INN: 9909522875, KPP: 997789001
# *A = taxable
# "B = tax-free
